# %%
headers_hl_hlasovani = ["id_hlasovani","id_organ","schuze","cislo","bod","datum","time","pro","proti","zdrzel","nehlasoval","prihlaseno","kvorum","druh_hlasovani","vysledek","nazev_dlouhy","nazev_kratky"]
headers_hl_poslanec = ["id_poslanec","id_hlasovani","vysledek"]
headers_omluvy = ["id_organ","id_poslanec","den","od","do"]
headers_hl_check = ["id_hlasovani","turn","mode","id_h2","id_h3"]
headers_hl_zposlanec = ["id_hlasovani","id_osoba","mode"]
headers_hl_vazby = ["id_hlasovani","turn","typ"]
headers_zmatecne = ["id_hlasovani"]
headers_li = ["id_los","datum_los","typ_los","cas_los","id_schuze","id_bod","schuze","id_org"]
headers_poradi = ["id_poradi","id_losovani","id_poslanec","id_ministr","vec","poradi_l","priorita","vec32"]
headers_ui_stav = ["id_poradi","id_typ","steno"]
headers_uitypv = ["id_ui_stav","nazev","priorita"]
headers_organy = ["id_organ","organ_id_organ","id_typ_organu","zkratka","nazev_organu_cz","nazev_organu_en","od_organ","do_organ","priorita","cl_organ_base"]
headers_funkce = ["id_funkce","id_organ","id_typ_funkce","nazev_funkce_cz","priorita"]
headers_typ_funkce = ["id_typ_funkce","id_typ_org","typ_funkce_cz","typ_funkce_en","priorita","typ_funkce_obecny"]
headers_typ_organu = ["id_typ_org","typ_id_typ_org","nazev_typ_org_cz","nazev_typ_org_en","typ_org_obecny","priorita"]
headers_osoby = ["id_osoba","title_pre","prijmeni","jmeno","title_post","narozeni","pohlavi", "zmena", "umrti"]
headers_zarazeni = ["id_osoba","id_of","cl_funkce","od_o","do_o","od_f","do_f"]
headers_poslanec = ["id_poslanec","id_osoba","id_kraj","id_kandidatka","id_obdobi","web","ulice","obec","psc","email","telefon","fax","psp_telefon","facebook","foto"]
headers_pkgps = ["id_poslanec","adresa","latitude","longitude"]
headers_osoba_extra = ["id_osoba","id_org","typ","obvod","strana","id_external"]
headers_sbirka = ["id_sbirka","cislo","rok","id_dp","id_tisk","datum","castka"]
headers_sb_pre = ["id_tisk","cz","id_sbirka","typ","zdroj","xzdroj"]
headers_druh_predpisu = ["id_dp","nazev_druhu","priorita"]
headers_schuze_stav = ["id_schuze","stav","typ","text_dt","text_st","tm_line"]
headers_bod_stav = ["id_bod_stav","popis"]
headers_bod_schuze = ["id_bod","id_schuze","id_tisk","id_typ","bod","uplny_naz","uplny_kon","poznamka","id_bod_stav","pozvanka","rj","pozn2","druh_bodu","id_sd","zkratka"]
headers_schuze = ["id_schuze","id_org","schuze_num","od_schuze","do_schuze","aktualizace","pozvanka"]
headers_sd = ["id_dokument","id_obdobi","cislo","typ","nazev","predkladatel","ct","id_x","end"]
headers_steno_bod = ["id_steno","aname","id_bod"]
headers_rec = ["id_steno","id_osoba","aname","id_bod","druh"]
headers_steno = ["id_steno","id_org","schuze","turn","od_steno","jd","od_t","do_t"]
headers_typ_zakon = ["id_navrh","druh_navrhovatele"]
headers_typ_stavu = ["id_typ","popis_stavu"]
headers_stavy = ["id_stav","id_typ","id_druh","popis","lhuta","lhuta_where"]
headers_typ_akce = ["id_akce","popis_akce"]
headers_prechody = ["id_prechod","odkud","kam","id_akce","typ_prechodu"]
headers_tisky = ["id_tisk","id_druh","id_stav","ct","cislo_za","id_navrh","id_org","id_org_obd","id_osoba","navrhovatel","nazev_tisku","predlozeno","rozeslano","dal","tech_nos_dat","uplny_nazev_tisku","zm_lhuty","lhuta","rj","t_url","is_eu","roz","is_sdv","status"]
headers_hist = ["id_hist","id_tisk","datum","id_hlas","id_prechod","id_bod","schuze","usnes_ps","orgv_id_posl","ps_id_posl","orgv_p_usn","zaver_publik","zaver_sb_castka","zaver_sb_cislo","poznamka"]
headers_hist_vybory = ["id_tisku","id_organ","typ","id_hist","id_posl","poradi"]
headers_vysledek = ["id_vysledek","druh_vysledek"]
headers_tisky_za = ["id_tisk","cislo_za","id_hist","id_druh","nazev_za","nazev_za","uplny_nazev_za","rozeslano","id_org","usn_vybor","id_posl","t_url","cislo_za_post","sort_it","roz","status"]
headers_predkladatel = ["id_tisk","id_osoba","poradi","typ"]
headers_navrh_podpis = ["id_tisk","id_osoba","stav","datum"]
headers_druh_tisku = ["id_druh","druh_t","nazev_druh"]
headers_se_tisk = ["id_tisk","id_druh","id_stav","cislo_tisku","id_obdobi","anotace","nazev_tisku"]
headers_psp2senat = ["id_psp","id_senat","typ"]
headers_se_druh_tisku = ["id_druh","nazev_druhu"]

# %%
data=[
# ["hl2021s", headers_hl_hlasovani,"hlasovani_hl_hlasovani"],
# ["hl2021h1", headers_hl_poslanec,"hlasovani_hl_poslanec"],
# ["omluvy", headers_omluvy,"hlasovani"],
# # ["hl2021s", headers_hl_check,"hlasovani_hl_check"],
# ["hl2021x", headers_hl_zposlanec,"hlasovani_hl_zposlanec"],
# ["hl2021v",headers_hl_vazby,"hlasovani_hl_vazby"],
# ["zmatecne", headers_zmatecne,"hlasovani"],
# ["uitypv",headers_uitypv,"interpelace"],
# ["li",headers_li,"interpelace"],
# ["poradi",headers_poradi,"interpelace"],
# ["p-stav",headers_ui_stav,"interpelace"],
# ["organy",headers_organy,"poslanci"],
# ["funkce",headers_funkce,"poslanci"],
# ["typ_funkce",headers_typ_funkce,"poslanci"],
# ["typ_organu",headers_typ_organu,"poslanci"],
# ["osoby",headers_osoby,"poslanci"],
# ["zarazeni",headers_zarazeni,"poslanci"],
# ["poslanec",headers_poslanec,"poslanci"],
# ["pkgps",headers_pkgps,"poslanci"],
# ["osoba_extra",headers_osoba_extra,"poslanci"],
# ["sbirka",headers_sbirka,"sbirka"],
# ["sb_pre",headers_sb_pre,"sbirka"],
# ["druh_predpisu",headers_druh_predpisu,"sbirka"],
# ["schuze_stav",headers_schuze_stav,"schuze"],
# ["bod_stav",headers_bod_stav,"schuze"],
# ["bod_schuze",headers_bod_schuze,"schuze"],
# ["schuze",headers_schuze,"schuze"],
# ["sd_dokument",headers_sd,"dokumenty"],
# ["steno_bod" ,headers_steno_bod,"steno"],
# ["rec" ,headers_rec,"steno"],
# ["steno" ,headers_steno,"steno"],
# ["druh_tisku",headers_druh_tisku,"tisk"],
# ["typ_zakon",headers_typ_zakon,"tisk"],
# ["typ_stavu",headers_typ_stavu,"tisk"],
# ["stavy",headers_stavy,"tisk"],
# ["typ_akce",headers_typ_akce,"tisk"],
# ["prechody",headers_prechody,"tisk"],
# # ["tisky",headers_tisky,"tisk"],
# ["hist",headers_hist,"tisk"],
# ["hist_vybory",headers_hist_vybory,"tisk"],
# ["vysledek",headers_vysledek,"tisk"],
# # ["tisky_za",headers_tisky_za,"tisk"],
# ["predkladatel",headers_predkladatel,"tisk"],
# # ["navrh_podpis",headers_navrh_podpis,"tisk"],
# ["psp2senat", headers_psp2senat,"senat"],
# ["se_tisk", headers_se_tisk ,"senat"],
# ["se_druh_tisku", headers_se_druh_tisku,"senat"]
]

# %%
import pandas as pd
import numpy as np


# Function to load CSV files into DataFrames
def load_csv(file_path, headers):
    return pd.read_csv(file_path, encoding="windows-1250", sep="|", header=None, names=headers, index_col=False, low_memory=False)


# Function to save DataFrame to a new CSV file
def save_csv(data_frame, file_path, headers):
    data_frame.to_csv(file_path, header=headers, index=False)


# Loop through the data list
for name, headers, prefix in data:
    file_path = f"C:\\Users\\jirip\\Documents\\Developer\\python\\poslanecka_snemovna_cr\\input\\{name}.unl"
    print(f'loaded {name}')
    # Load CSV file into DataFrame
    data_frame = load_csv(file_path, headers)
    

    # Perform operations on the DataFrame if needed
    float_columns = data_frame.select_dtypes(include='float64').columns
    data_frame[float_columns] = data_frame[float_columns].replace([np.inf, -np.inf], np.nan).fillna(0).astype(int)


    # Save the updated DataFrame to a new CSV file
    save_csv(data_frame, f"C:\\Users\\jirip\\Documents\\Developer\\python\\poslanecka_snemovna_cr\\output\\{prefix}_{name}.csv", headers)
    print(f'saved {prefix}_{name}')
# Out:
# loaded osoby
# saved poslanci_osoby
